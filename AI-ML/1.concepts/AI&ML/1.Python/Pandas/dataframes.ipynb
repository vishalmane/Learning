# %%
import numpy as np
import pandas as pd

from numpy.random import ra
ndn

# %%
np.random.seed(101)

# %%
df= pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df['W']

# %%
df['W']['A']

# %%
df['new']= df['W'] + df['X']
df

# %%
df.drop('new', axis=1,inplace=True)
df

# %%
df.loc['A']

# %%
booldf= df > 0
df[booldf]

# %%
df[(df['W']>0 ) & (df['Y'] > 1)]

# %%
new_index= 'NA CA WA DA MH'.split()
new_index

# %%
df['States']= new_index
df

# %%
df.set_index('States')
